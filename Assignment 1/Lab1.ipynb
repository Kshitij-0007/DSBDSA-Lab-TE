# %%
import pandas as pd

# %%
df=pd.read_excel("C:/Users/Kshitij/OneDrive/Desktop/DSBDAL/Assignment 1/Data/Demo Marks.xlsx")

# %%
df.head(10)
# Out:
#    Roll no            Name of Student  \
# 0        1          RAVAL MEET MAHESH
# 1        2      HUMBE BHAKTI RAJENDRA
# 2        3  MARATHE SANSKRUTI JAGDISH
# 3        4      THAKARE MRUNALI VINOD
# 4        5    BHONGALE OMKAR MADHUKAR
# 5        6    THETE SANJIVANI SANTOSH
# 6        7    KHATAL NANDINI RAJENDRA
# 7        8       SHELKE GAURAV GIRISH
# 8        9            DEVANSHU SHARMA
# 9       10   SAHASRABUDHE SOHAM MILIN
#
#    Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                         1131  80.785714          29
# 1                                         1107  79.071429          29
# 2                                          995  71.071429          27
# 3                                         1077  76.928571          28
# 4                                         1064  76.000000          28
# 5                                         1129  80.642857          29
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 9 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Roll no                                      74 non-null     int64
#  1   Name of Student                              74 non-null     str
#  2   Previous Year SPPU Total Marks out of  1400  74 non-null     int64
#  3   %                                            74 non-null     float64
#  4   UT 1 Marks                                   74 non-null     int64
#  5   %.1                                          74 non-null     float64
#  6   50% maks of Previous Year SPPU Result        74 non-null     float64
#  7   50% Marks of Unit Test 1                     74 non-null     int64
#  8   Total 100%                                   74 non-null     float64
# dtypes: float64(4), int64(4), str(1)
# memory usage: 5.3 KB

# %%
print(df)
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131  80.785714          29
# 1                                          1107  79.071429          29
# 2                                           995  71.071429          27
# 3                                          1077  76.928571          28
# 4                                          1064  76.000000          28
# ...

# %%
df.describe()
# Out:
#          Roll no  Previous Year SPPU Total Marks out of  1400          %  \
# count  74.000000                                    74.000000  74.000000
# mean   37.500000                                   951.567568  67.969112
# std    21.505813                                   141.310024  10.093573
# min     1.000000                                   542.000000  38.714286
# 25%    19.250000                                   880.000000  62.857143
# 50%    37.500000                                   970.000000  69.285714
# 75%    55.750000                                  1059.750000  75.696429
# max    74.000000                                  1203.000000  85.928571
#
#        UT 1 Marks        %.1  50% maks of Previous Year SPPU Result  \
# count   74.000000  74.000000                              74.000000
# mean    23.432432  78.108108                              34.394788
# std      4.935422  16.451405                               5.595003
# ...

# %%
print(df.duplicated(keep="first"))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Length: 74, dtype: bool

# %%
df.isnull().sum()
# Out:
# Roll no                                        0
# Name of Student                                0
# Previous Year SPPU Total Marks out of  1400    0
# %                                              0
# UT 1 Marks                                     0
# %.1                                            0
# 50% maks of Previous Year SPPU Result          0
# 50% Marks of Unit Test 1                       0
# Total 100%                                     0
# dtype: int64

# %%
df.loc[4]
# Out:
# Roll no                                                              5
# Name of Student                                BHONGALE OMKAR MADHUKAR
# Previous Year SPPU Total Marks out of  1400                       1064
# %                                                                 76.0
# UT 1 Marks                                                          28
# %.1                                                          93.333333
# 50% maks of Previous Year SPPU Result                             42.0
# 50% Marks of Unit Test 1                                            38
# Total 100%                                                        80.0
# Name: 4, dtype: object

# %%
df2=df.iloc[:,:4]

# %%
df2
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %
# 0                                          1131  80.785714
# 1                                          1107  79.071429
# 2                                           995  71.071429
# 3                                          1077  76.928571
# 4                                          1064  76.000000
# ..                                          ...        ...
# 69                                          725  51.785714
# ...
